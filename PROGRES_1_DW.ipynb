# %%
import pandas as pd

# Baca dataset
df = pd.read_csv("diabetes_prediction_dataset.csv")

# Tampilkan 5 data awal
print(df.head())

# Informasi dataset
print(df.info())

# Ukuran dataset
print("Jumlah baris dan kolom:")
print(df.shape)
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB
# None
# Jumlah baris dan kolom:
# (100000, 9)

# %%
import os

os.listdir()
# Out:
# ['.config', 'diabetes_prediction_dataset.csv', 'sample_data']

# %%
# Ukuran dataset
print(df.shape)

# Missing value
print(df.isnull().sum())

# Distribusi diabetes
print(df["diabetes"].value_counts())

# Statistik numerik
print(df.describe())
# Out:
# (100000, 9)
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# 50%         5.800000           140.000000       0.000000
# 75%         6.200000           159.000000       0.000000
# max         9.000000           300.000000       1.000000

# %%
# Ukuran dataset
print(df.shape)

# Missing value
print(df.isnull().sum())

# Distribusi diabetes
print(df["diabetes"].value_counts())

# Statistik numerik
print(df.describe())
# Out:
# (100000, 9)
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# 50%         5.800000           140.000000       0.000000
# 75%         6.200000           159.000000       0.000000
# max         9.000000           300.000000       1.000000

# %%
print(df.dtypes)
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
print("Missing value:")
print(df.isnull().sum())
# Out:
# Missing value:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
print("Jumlah duplikat:")
print(df.duplicated().sum())
# Out:
# Jumlah duplikat:
# 3854

# %%
print(df["diabetes"].value_counts())
# Out:
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64

# %%
major=85000
minor=15000

print(major/minor)
# Out:
# 5.666666666666667

# %%
print(df.describe())
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# 50%         5.800000           140.000000       0.000000
# 75%         6.200000           159.000000       0.000000
# max         9.000000           300.000000       1.000000

# %%
import matplotlib.pyplot as plt

kolom=[
'age',
'bmi',
'HbA1c_level',
'blood_glucose_level'
]

for k in kolom:
    plt.figure(figsize=(4,2))
    plt.boxplot(df[k],vert=False)
    plt.title(k)
    plt.show()

# %%
import pandas as pd

df['record_date']=pd.date_range(
start='2024-01-01',
periods=len(df),
freq='h'
)

print(df.head())
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes         record_date
# 0          6.6                  140         0 2024-01-01 00:00:00
# 1          6.6                   80         0 2024-01-01 01:00:00
# 2          5.7                  158         0 2024-01-01 02:00:00
# 3          5.0                  155         0 2024-01-01 03:00:00
# 4          4.8                  155         0 2024-01-01 04:00:00

# %%
print(df.shape)
# Out:
# (100000, 10)

# %%
print(df.isnull().sum())
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# record_date            0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df['diabetes'].value_counts())
# Out:
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64

# %%
print(df.describe())
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
# std        22.516840       0.26315       0.194593       6.636783
#
#          HbA1c_level  blood_glucose_level       diabetes  \
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# 50%         5.800000           140.000000       0.000000
# 75%         6.200000           159.000000       0.000000
# max         9.000000           300.000000       1.000000
# std         1.070672            40.708136       0.278883
#
#                          record_date
# count                         100000
# mean   2029-09-14 07:29:59.999999744
# min              2024-01-01 00:00:00
# 25%              2026-11-07 15:45:00
# 50%              2029-09-14 07:30:00
# 75%              2032-07-21 23:15:00
# max              2035-05-29 15:00:00
# std                              NaN

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3))
plt.boxplot(df['bmi'],vert=False)
plt.title("BMI")
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.boxplot(df['HbA1c_level'],vert=False)
plt.title("HbA1c")
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.boxplot(df['blood_glucose_level'],vert=False)
plt.title("Blood Glucose")
plt.show()
